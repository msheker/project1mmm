# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
def f(x):
    return np.int(x)
f2 = np.vectorize(f)

# %%
bias_location = pd.read_excel('table10_clean.xls')

# %%
bias_location = bias_location[bias_location['Location'] != 'Total']
bias_location
# Out:
#                                          Location  Total incidents  \
# 1                   Abandoned/condemned structure                4
# 2                          Air/bus/train terminal              113
# 3                                  Amusement park                3
# 4              Arena/stadium/fairgrounds/coliseum                7
# 5                          ATM separate from bank                2
# 6                        Auto dealership new/used                8
# 7                           Bank/savings and loan               28
# 8                                   Bar/nightclub              119
# 9                                 Camp/campground                4
# 10                 Church/synagogue/temple/mosque              263
# 11                     Commercial office building              145
# 12                               Community center               20
# 13                              Construction site               20
# 14                              Convenience store              141
# 15                                     Cyberspace               23
# 16                               Daycare facility                2
# 17                      Department/discount store              111
# 18              Dock/wharf/freight/modal terminal                1
# 19            Drug store/doctor's office/hospital               93
# 20                                  Farm facility                5
# 21                                    Field/woods               47
# 22            Gambling facility/casino/race track                3
# 23                     Government/public building              163
# 24                            Grocery/supermarket               98
# 25             Highway/road/alley/street/sidewalk             1328
# 26                               Hotel/motel/etc.               67
# 27                                Industrial site                7
# 28  Jail/prison/penitentiary/corrections facility               69
# 29                            Lake/waterway/beach                8
# 30                                   Liquor store               13
# 31                          Military installation                0
# 32                                Park/playground              106
# 33                        Parking/drop lot/garage              380
# 34                        Rental storage facility               12
# 35                                 Residence/home             1832
# 36                                      Rest area                8
# 37                                     Restaurant              189
# 38                                School/college2               69
# 39                      School—college/university              314
# 40                    School—elementary/secondary              273
# 41                            Service/gas station               91
# 42                       Shelter—mission/homeless               18
# 43                                  Shopping mall               21
# 44                Specialty store (TV, fur, etc.)               79
# 45                                   Tribal Lands                1
# 46                                  Other/unknown              800
# 47                             Multiple locations               12
#
#     Race/Ethnicity/Ancestry  Religion  Sexual orientation  Disability  Gender  \
# 1                         3         1                   0           0       0
# 2                        67         2                  34           1       1
# 3                         2         0                   0           0       0
# 4                         2         1                   3           0       0
# 5                         1         0                   0           0       0
# 6                         5         1                   2           0       0
# 7                        14         8                   2           3       0
# 8                        53         3                  59           1       0
# 9                         4         0                   0           0       0
# 10                       29       219                  12           0       0
# 11                       97        22                  16           1       3
# 12                        8         5                   4           1       0
# 13                       13         4                   2           0       0
# 14                      100        13                  19           4       0
# 15                       15         4                   2           1       0
# 16                        2         0                   0           0       0
# 17                       63        20                  11           4       2
# 18                        1         0                   0           0       0
# 19                       63        12                   7           7       0
# 20                        3         1                   1           0       0
# 21                       31         5                   7           2       0
# 22                        3         0                   0           0       0
# 23                      116        22                  12           4       2
# 24                       75         5                  10           3       0
# 25                      846       143                 259          23       4
# 26                       41         6                  17           2       0
# 27                        5         0                   0           1       1
# 28                       45         3                  19           1       0
# 29                        4         1                   2           0       0
# 30                        6         0                   4           0       1
# 31                        0         0                   0           0       0
# 32                       68        15                  20           0       0
# 33                      245        57                  59           8       3
# 34                        8         3                   0           1       0
# 35                     1044       303                 352          66      18
# 36                        2         6                   0           0       0
# 37                      136        15                  30           0       1
# 38                       35        17                  11           1       0
# 39                      155        88                  53           5       5
# 40                      153        59                  33           6       0
# 41                       63        12                  10           2       0
# 42                        9         4                   2           0       0
# 43                       14         1                   5           0       0
# 44                       56        10                   7           1       1
# 45                        1         0                   0           0       0
# 46                      334       327                 108           9       5
# 47                        7         1                   2           1       0
#
#     Gender Identity  Multiple Bias Incidents
# 1                 0                        0
# 2                 6                        2
# 3                 1                        0
# 4                 1                        0
# 5                 1                        0
# 6                 0                        0
# 7                 1                        0
# 8                 2                        1
# 9                 0                        0
# 10                0                        3
# 11                4                        2
# 12                1                        1
# 13                0                        1
# 14                5                        0
# 15                0                        1
# 16                0                        0
# 17                6                        5
# 18                0                        0
# 19                2                        2
# 20                0                        0
# 21                1                        1
# 22                0                        0
# 23                2                        5
# 24                5                        0
# 25               42                       11
# 26                1                        0
# 27                0                        0
# 28                1                        0
# 29                0                        1
# 30                2                        0
# 31                0                        0
# 32                3                        0
# 33                7                        1
# 34                0                        0
# 35               33                       16
# 36                0                        0
# 37                6                        1
# 38                4                        1
# 39                3                        5
# 40                5                       17
# 41                4                        0
# 42                3                        0
# 43                0                        1
# 44                2                        2
# 45                0                        0
# 46               13                        4
# 47                1                        0

# %%
p1 = plt.bar(bias_location['Location'], f2(bias_location['Race/Ethnicity/Ancestry']))
p2 = plt.bar(bias_location['Location'], f2(bias_location['Religion']), bottom = f2(bias_location['Race/Ethnicity/Ancestry']))
p3 = plt.bar(bias_location['Location'], f2(bias_location['Sexual orientation']), bottom = f2(bias_location['Religion'])+ f2(bias_location['Race/Ethnicity/Ancestry']))
p4 = plt.bar(bias_location['Location'], f2(bias_location['Disability']),bottom = f2(bias_location['Sexual orientation'])+f2(bias_location['Religion'])+ f2(bias_location['Race/Ethnicity/Ancestry']))
p5 = plt.bar(bias_location['Location'], f2(bias_location['Gender']),bottom =f2(bias_location['Disability'])+ f2(bias_location['Sexual orientation'])+f2(bias_location['Religion'])+ f2(bias_location['Race/Ethnicity/Ancestry']))
p6 = plt.bar(bias_location['Location'], f2(bias_location['Gender Identity']),bottom =f2(bias_location['Gender']) +f2(bias_location['Disability'])+ f2(bias_location['Sexual orientation'])+f2(bias_location['Religion'])+ f2(bias_location['Race/Ethnicity/Ancestry']))
p7 = plt.bar(bias_location['Location'], f2(bias_location['Multiple Bias Incidents']),bottom =f2(bias_location['Gender Identity'])+f2(bias_location['Gender']) +f2(bias_location['Disability'])+ f2(bias_location['Sexual orientation'])+f2(bias_location['Religion'])+ f2(bias_location['Race/Ethnicity/Ancestry']))

plt.title('Incicidents by Location')
plt.xticks(bias_location['Location'], rotation=90)
plt.legend((p1[0], p2[0], p3[0], p4[0], p5[0],p6[0], p7[0]), ('Race/Ethnicity/Ancestry', 'Religion','Sexual orientation', 'Disability', 'Gender', 'Gender Identity','Multiple Bias Incidents' ), prop={'size': 10})

plt.rcParams['figure.figsize'] = (20, 3)
plt.show()
